# %%
import os
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
import pandas as pd
import numpy as np
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
app = dash.Dash(__name__, external_stylesheets=external_stylesheets,suppress_callback_exceptions = True)
df=pd.read_csv('/Users/nathanmitch/Desktop/sundress/L5T5Crime.csv')
df.columns = df.columns.str.replace(' ', '')
df=df.sample(frac=0.001, replace=True, random_state=1)
df.head()
# Out:
#         Unnamed:0        ID                 Date      PrimaryType  \
# 128037    1224147   9768095  2014-09-06 19:00:00            THEFT
# 491755     668937  10705119  2016-10-04 21:58:00          ASSAULT
# 470924     701013  10663977  2016-08-25 09:00:00            THEFT
# 791624     203474  11373463  2018-07-08 00:45:00            THEFT
# 491263     669763  10704184  2016-10-03 19:30:00  CRIMINAL DAMAGE
#
#        LocationDescription  Arrest  District   Latitude  Longitude  \
# 128037           RESIDENCE   False       5.0  41.682224 -87.624028
# 491755  SMALL RETAIL STORE   False      11.0  41.901823 -87.726278
# 470924               OTHER   False      22.0  41.691319 -87.716835
# 791624          RESTAURANT   False      18.0  41.890053 -87.628704
# 491263              STREET   False      22.0  41.728376 -87.638545
#
#         XCoordinate  YCoordinate  Year  Month  Day  Weekday  HourOfDay
# 128037    1178005.0    1827592.0  2014      9    6        5         19
# 491755    1149509.0    1907399.0  2016     10    4        1         21
# 470924    1152630.0    1830711.0  2016      8   25        3          9
# 791624    1176107.0    1903313.0  2018      7    8        6          0
# 491263    1173904.0    1844377.0  2016     10    3        0         19

# %%
app.layout = html.Div([
    html.Div([html.H1("ChicagoCrime")], style={"textAlign": "center"}),
    html.Div([html.Div([html.Div([html.Span("Scatter Plot x-axis", className="three columns",
                                            style={"width": 150, "padding": 10, "text-align": "right"}),
                                  html.Div(dcc.Dropdown(id="xaxis",
                                                        options=[{"label":"Type of Crime","value":"PrimaryType"},
                                                                 {"label":"Type of Location","value":"LocationDescription"},
                                                                 {"label":"Chicago District","value":"District"},
                                                                 {"label":"Year","value":"Year"},
                                                                 {"label":"Month","value":"Month"},
                                                                 {"label":"Day","value":"Day"},
                                                                 {"label":"Weekday","value":"Weekday"},
                                                                 {"label":"HourOfDay","value":"HourOfDay"}],
                                                        value='Year', ), className="three columns",
                                           style={"width": 250, "margin": 0})], className="row"),
                        html.Div([html.Span("Scatter Plot y-axis", className="three columns",
                                            style={"width": 150, "padding": 10, "text-align": "right"}),
                                  html.Div(dcc.Dropdown(id="yaxis",
                                                        options=[{"label":"Type of Crime","value":"PrimaryType"},
                                                                 {"label":"Type of Location","value":"LocationDescription"},
                                                                 {"label":"Chicago District","value":"District"},
                                                                 {"label":"Year","value":"Year"},
                                                                 {"label":"Month","value":"Month"},
                                                                 {"label":"Day","value":"Day"},
                                                                 {"label":"Weekday","value":"Weekday"},
                                                                 {"label":"HourOfDay","value":"HourOfDay"}],
                                                        value='PrimaryType', ), className="three columns",
                                           style={"width": 250, "margin": 0})], className="row"),
                        html.Div([html.Span("Bar Plot y-axis", className="three columns",
                                            style={"width": 150, "padding": 10, "text-align": "right"}),
                                  html.Div(dcc.Dropdown(id="barplot-yaxis",
                                                        options=[{"label":"Type of Crime","value":"PrimaryType"},
                                                                 {"label":"Type of Location","value":"LocationDescription"},
                                                                 {"label":"Chicago District","value":"District"},
                                                                 {"label":"Year","value":"Year"},
                                                                 {"label":"Month","value":"Month"},
                                                                 {"label":"Day","value":"Day"},
                                                                 {"label":"Weekday","value":"Weekday"},
                                                                 {"label":"HourOfDay","value":"HourOfDay"}],
                                                        value='District', ), className="three columns",
                                           style={"width": 250, "margin": 0})], className="row"), ],
                       style={'width': '48%', 'display': 'inline-block'}, className="six columns"),
              html.Div([html.Div([html.Span("Box Plot x-axis", className="three columns",
                                            style={"text-align": "right", "width": "30%", "padding": 5}),
                                  html.Div(dcc.RadioItems(id="select-value", value='True',
                                                          options=[{'label': "Arrest", 'value': "Arrest"},
                                                                   {'label': "Weekday", 'value': "Weekday"}],
                                                          labelStyle={'display': 'inline', "padding": 7.5}),
                                           className="three columns",
                                           style={"width": "50%", "margin": 0, "padding": 5})], className="row"),
                        html.Div([html.Span("Box Plot y-axis", className="three columns",
                                            style={"width": 150, "padding": 10, "text-align": "right"}),
                                  html.Div(dcc.Dropdown(id="boxplot-yaxis",
                                                        options=[{"label":"Type of Crime","value":"PrimaryType"},
                                                                 {"label":"Type of Location","value":"LocationDescription"},
                                                                 {"label":"Chicago District","value":"District"},
                                                                 {"label":"Year","value":"Year"},
                                                                 {"label":"Month","value":"Month"},
                                                                 {"label":"Day","value":"Day"},
                                                                 {"label":"Weekday","value":"Weekday"},
                                                                 {"label":"HourOfDay","value":"HourOfDay"}],
                                                        value='LocationDescription', ), className="three columns",
                                           style={"width": 250, "margin": 0})], className="row")
                        ], style={'width': '50%', 'float': 'right', 'display': 'inline-block', "margin-left": "auto",
                                  "margin-right": "auto", "padding-top": 30}, className="six columns")],
             className="row"),
    html.Div([dcc.Graph(id="my-graph")]),
], className="container")


@app.callback(
    dash.dependencies.Output("my-graph", "figure"),
    [dash.dependencies.Input("xaxis", "value"), dash.dependencies.Input("yaxis", "value"),
     dash.dependencies.Input("boxplot-yaxis", "value"), dash.dependencies.Input("select-value", "value"),
     dash.dependencies.Input("barplot-yaxis", "value")])
def update_graph(selected1, selected2, selected_box_y, selected_box_x, selected_bar_y):
    trace1 = [go.Scatter(x=df[selected1], y=df[selected2], text=df['PrimaryType'], mode='markers', opacity=0.8,
                         marker={'size': 10, "color": "#00CC94", }, showlegend=False, )]

    trace2 = [go.Box(x=df[selected_box_x], y=df[selected_box_y],
                     name=f'{"Arrest" if selected_box_x == "True" else "False"}', showlegend=False,
                     xaxis='x2', yaxis='y2', marker={"color": "#4CEB00"})]
    trace3 = [go.Bar(x=df['LocationDescription'], y=df[selected_bar_y], xaxis='x3', yaxis='y3', showlegend=False,
                     marker={"color": "#5DB4F2", "opacity": 0.9})]

    trace = trace1 + trace2 + trace3
    text = {"PrimaryType": "PrimaryType", "LocationDescription": "LocationDescription", "District": "District",
            "Year": "Year", "Month": "Month", "Day": "Day","Weekday":"Weekday","HourOfDay":"HourOfDay"}
    return {"data": trace,
            "layout": go.Layout(height=1000, width=1200, annotations=[
                {"x": 0.07, "y": 1, "xref": "paper", "yref": "paper","font": {"size": 12},
                 "text": f'{text[selected2].title()} vs {text[selected1].title()}', "showarrow": False},
                {"x": 0.85, "y": 1, "xref": "paper", "yref": "paper","showarrow": False, "font": {"size": 12},
                 "text": f'{text[selected_box_y].title()} vs 'f'{"Arrest" if selected_box_x == "True" else "Day of Week"}'},
                {"x": 0.5, "y": 0.45, "xref": "paper", "yref": "paper",
                 "text": f'{text[selected_bar_y].title()} LocationDescription', "showarrow": False, "font": {"size": 15}}],
                                xaxis={"title": text[selected1].title(), "domain": [0, 0.40], "anchor": 'y', },
                                yaxis={"title": text[selected2].title(), "domain": [0.65, 1], "anchor": 'x'}, xaxis2={
                    "title": f'{"NoArrest   Arrested " if selected_box_x == "True" else "Day of Week "}',
                    "domain": [0.55, 1], "anchor": 'y2',
                    "showticklabels": False, },
                                yaxis2={"title": text[selected_box_y].title(), "domain": [0.55, 1], "anchor": 'x2'},
                                xaxis3={"tickangle": -38, "domain": [0, 1], "anchor": 'y3'},
                                yaxis3={"title": text[selected_bar_y].title(), "domain": [0, 0.45], "anchor": 'x3'})
            }

# %%
if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [11/May/2019 10:54:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [11/May/2019 10:54:07] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [11/May/2019 10:54:07] "GET /_dash-layout HTTP/1.1" 200 -
# [2019-05-11 10:54:07,065] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 2657, in get_loc
#     return self._engine.get_loc(key)
#   File "pandas/_libs/index.pyx", line 108, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 132, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1601, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1608, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'True'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/flask/_compat.py", line 35, in reraise
#     raise value
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/dash/dash.py", line 1151, in dispatch
#     response.set_data(self.callback_map[output]['callback'](*args))
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/dash/dash.py", line 1037, in add_context
#     output_value = func(*args, **kwargs)
#   File "<ipython-input-2-367f00604cf7>", line 80, in update_graph
#     trace2 = [go.Box(x=df[selected_box_x], y=df[selected_box_y],
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/pandas/core/frame.py", line 2927, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 2659, in get_loc
#     return self._engine.get_loc(self._maybe_cast_indexer(key))
#   File "pandas/_libs/index.pyx", line 108, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 132, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1601, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1608, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'True'
# 127.0.0.1 - - [11/May/2019 10:54:07] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [11/May/2019 10:54:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [11/May/2019 10:54:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [11/May/2019 10:54:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [11/May/2019 10:54:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [11/May/2019 10:55:13] "POST /_dash-update-component HTTP/1.1" 200 -
# [2019-05-11 10:55:18,734] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 2657, in get_loc
#     return self._engine.get_loc(key)
#   File "pandas/_libs/index.pyx", line 108, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 132, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1601, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1608, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/flask/_compat.py", line 35, in reraise
#     raise value
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/dash/dash.py", line 1151, in dispatch
#     response.set_data(self.callback_map[output]['callback'](*args))
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/dash/dash.py", line 1037, in add_context
#     output_value = func(*args, **kwargs)
#   File "<ipython-input-2-367f00604cf7>", line 83, in update_graph
#     trace3 = [go.Bar(x=df['LocationDescription'], y=df[selected_bar_y], xaxis='x3', yaxis='y3', showlegend=False,
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/pandas/core/frame.py", line 2927, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/anaconda3/envs/sun2/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 2659, in get_loc
#     return self._engine.get_loc(self._maybe_cast_indexer(key))
#   File "pandas/_libs/index.pyx", line 108, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 132, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1601, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1608, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
# 127.0.0.1 - - [11/May/2019 10:55:18] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [11/May/2019 10:55:22] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
app.layout = html.Div([
    html.Div([html.H1("ChicagoCrime")], style={"textAlign": "center"}),
    html.Div([html.Div([html.Div([html.Span("Scatter Plot x-axis", className="three columns",
                                            style={"width": 150, "padding": 10, "text-align": "right"}),
                                  html.Div(dcc.Dropdown(id="xaxis",
                                                        options=[{"label":"Type of Crime","value":"PrimaryType"},
                                                                 {"label":"Type of Location","value":"LocationDescription"},
                                                                 {"label":"Chicago District","value":"District"},
                                                                 {"label":"Year","value":"Year"},
                                                                 {"label":"Month","value":"Month"},
                                                                 {"label":"Day","value":"Day"},
                                                                 {"label":"Weekday","value":"Weekday"},
                                                                 {"label":"HourOfDay","value":"HourOfDay"}],
                                                        value='Year', ), className="three columns",
                                           style={"width": 250, "margin": 0})], className="row"),
                        html.Div([html.Span("Scatter Plot y-axis", className="three columns",
                                            style={"width": 150, "padding": 10, "text-align": "right"}),
                                  html.Div(dcc.Dropdown(id="yaxis",
                                                        options=[{"label":"Type of Crime","value":"PrimaryType"},
                                                                 {"label":"Type of Location","value":"LocationDescription"},    {"label":"Chicago District","value":"District"},
                                                                 {"label":"Year","value":"Year"},
                                                                 {"label":"Month","value":"Month"},
                                                                 {"label":"Day","value":"Day"},
                                                                 {"label":"Weekday","value":"Weekday"},
                                                                 {"label":"HourOfDay","value":"HourOfDay"}],
                                                        value='PrimaryType', ), className="three columns",
                                           style={"width": 250, "margin": 0})], className="row"),
                        html.Div([html.Span("Bar Plot y-axis", className="three columns",
                                            style={"width": 150, "padding": 10, "text-align": "right"}),
                                  html.Div(dcc.Dropdown(id="barplot-yaxis",
                                                        options=[{"label":"Type of Crime","value":"PrimaryType"},
                                                                 {"label":"Type of Location","value":"LocationDescription"},    {"label":"Chicago District","value":"District"},
                                                                 {"label":"Year","value":"Year"},
                                                                 {"label":"Month","value":"Month"},
                                                                 {"label":"Day","value":"Day"},
                                                                 {"label":"Weekday","value":"Weekday"},
                                                                 {"label":"HourOfDay","value":"HourOfDay"}],
                                                        value='District', ), className="three columns",
                                           style={"width": 250, "margin": 0})], className="row"), ],
                       style={'width': '48%', 'display': 'inline-block'}, className="six columns"),
              html.Div([html.Div([html.Span("Box Plot x-axis", className="three columns",
                                            style={"text-align": "right", "width": "30%", "padding": 5}),
                                  html.Div(dcc.RadioItems(id="select-value", value='True',
                                                          options=[{'label': "Arrested", 'value': "Arrest"},
                                                                   {'label': "NoArrest", 'value': "Arrest"}],
                                                          labelStyle={'display': 'inline', "padding": 7.5}),
                                           className="three columns",
                                           style={"width": "50%", "margin": 0, "padding": 5})], className="row"),
                        html.Div([html.Span("Box Plot y-axis", className="three columns",
                                            style={"width": 150, "padding": 10, "text-align": "right"}),
                                  html.Div(dcc.Dropdown(id="boxplot-yaxis",
                                                        options=[{"label":"Type of Crime","value":"PrimaryType"},
                                                                 {"label":"Type of Location","value":"LocationDescription"},    {"label":"Chicago District","value":"District"},
                                                                 {"label":"Year","value":"Year"},
                                                                 {"label":"Month","value":"Month"},
                                                                 {"label":"Day","value":"Day"},
                                                                 {"label":"Weekday","value":"Weekday"},
                                                                 {"label":"HourOfDay","value":"HourOfDay"}],
                                                        value='LocationDescription', ), className="three columns",
                                           style={"width": 250, "margin": 0})], className="row")
                        ], style={'width': '50%', 'float': 'right', 'display': 'inline-block', "margin-left": "auto",
                                  "margin-right": "auto", "padding-top": 30}, className="six columns")],
             className="row"),
    html.Div([dcc.Graph(id="my-graph")]),
], className="container")


@app.callback(
    dash.dependencies.Output("my-graph", "figure"),
    [dash.dependencies.Input("xaxis", "value"), dash.dependencies.Input("yaxis", "value"),
     dash.dependencies.Input("boxplot-yaxis", "value"), dash.dependencies.Input("select-value", "value"),
     dash.dependencies.Input("barplot-yaxis", "value")])
def update_graph(selected1, selected2, selected_box_y, selected_box_x, selected_bar_y):
    trace1 = [go.Scatter(x=df[selected1], y=df[selected2], text=df['PrimaryType'], mode='markers', opacity=0.8,
                         marker={'size': 10, "color": "#00CC94", }, showlegend=False, )]

    trace2 = [go.Box(x=df[selected_box_x], y=df[selected_box_y],
                     name=f'{"Arrest" if selected_box_x == "True" else "False"}', showlegend=False,
                     xaxis='x2', yaxis='y2', marker={"color": "#4CEB00"})]
    trace3 = [go.Bar(x=df['LocationDescription'], y=df[selected_bar_y], xaxis='x3', yaxis='y3', showlegend=False,
                     marker={"color": "#5DB4F2", "opacity": 0.9})]

    trace = trace1 + trace2 + trace3
    text = {"PrimaryType": "PrimaryType", "LocationDescription": "LocationDescription", "District": "District",
            "Year": "Year", "Month": "Month", "Day": "Day","Weekday":"Weekday","HourOfDay":"HourOfDay"}
    return {"data": trace,
            "layout": go.Layout(height=850, width=1000, annotations=[
                {"x": 0.07, "y": 1, "xref": "paper", "yref": "paper","font": {"size": 12},
                 "text": f'{text[selected2].title()} vs {text[selected1].title()}', "showarrow": False},
                {"x": 0.85, "y": 1, "xref": "paper", "yref": "paper","showarrow": False, "font": {"size": 12},
                 "text": f'{text[selected_box_y].title()} vs 'f'{"Arrest" if selected_box_x == "True" else "False"}'},
                {"x": 0.5, "y": 0.45, "xref": "paper", "yref": "paper",
                 "text": f'{text[selected_bar_y].title()} LocationDescription', "showarrow": False, "font": {"size": 15}}],
                                xaxis={"title": text[selected1].title(), "domain": [0, 0.40], "anchor": 'y', },
                                yaxis={"title": text[selected2].title(), "domain": [0.65, 1], "anchor": 'x'}, xaxis2={
                    "title": f'{"Arrested   NoArrest " if selected_box_x == "True" else "Arrested   NoArrest "}',
                    "domain": [0.55, 1], "anchor": 'y2',
                    "showticklabels": False, },
                                yaxis2={"title": text[selected_box_y].title(), "domain": [0.55, 1], "anchor": 'x2'},
                                xaxis3={"tickangle": -38, "domain": [0, 1], "anchor": 'y3'},
                                yaxis3={"title": text[selected_bar_y].title(), "domain": [0, 0.45], "anchor": 'x3'})
            }
