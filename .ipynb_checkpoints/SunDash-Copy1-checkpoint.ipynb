# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import pandas as pd
import flask
import plotly.plotly as py
import plotly.graph_objs as go


import plotly

# %%
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
app = dash.Dash(__name__, external_stylesheets=external_stylesheets)
df=pd.read_csv('/Users/nathanmitch/Desktop/sundress/L5T5Crime.csv')
df.columns = df.columns.str.replace(' ', '')
df=df.sample(frac=0.1, replace=True, random_state=1)

# %%
app.layout = html.Div([
    html.Div([html.H1("Chicago Crime Reports")],style={"textAlign":"center"}),
    html.Div([html.Span("Scatter Plot x-axis",
                        style={'width': '49%', 'display': 'inline-block'}),
              html.Div(dcc.Dropdown(id="sxaxis",
                                    options=[{"label":"Type","value":"PrimaryType"},
                                             {"label":"Location","value":"LocationDescription"},
                                             {"label":"District","value":"District"},
                                             {"label":"Year","value":"Year"},
                                             {"label":"Month","value":"Month"},
                                             {"label":"Day","value":"Day"},
                                             {"label":"Weekday","value":"Weekday"},
                                             {"label":"Arrest","value":"Arrest"}],
                                    value="Year",),
                       style={"width":"49%"})]),
    html.Div([html.Span("Scatter Plot y-axis",style={'width': '49%', 'display': 'inline-block'}),
              html.Div(dcc.Dropdown(id="syaxis",
                                    options=[{"label":"Type","value":"PrimaryType"},
                                             {"label":"Location","value":"LocationDescription"},
                                             {"label":"District","value":"District"},
                                             {"label":"Year","value":"Year"},
                                             {"label":"Month","value":"Month"},
                                             {"label":"Day","value":"Day"},
                                             {"label":"Weekday","value":"Weekday"},
                                             {"label":"Arrest","value":"Arrest"}],
                                    value="District",),
                       style={"width":"49%"})]),                        
    html.Div([html.Span("Bar Plot x-axis",style={'width': '49%', 'display': 'inline-block'}),
              html.Div(dcc.Dropdown(id="bxaxis",
                                    options=[{"label":"Type","value":"PrimaryType"},
                                             {"label":"Location","value":"LocationDescription"},
                                             {"label":"District","value":"District"},
                                             {"label":"Year","value":"Year"},
                                             {"label":"Month","value":"Month"},
                                             {"label":"Day","value":"Day"},
                                             {"label":"Weekday","value":"Weekday"},
                                             {"label":"Arrest","value":"Arrest"}],
                                    value="Year",),
                       style={"width":"49%"})]),             
    html.Div([html.Span("Bar Plot y-axis",style={'width': '49%', 'display': 'inline-block'}),
              html.Div(dcc.Dropdown(id="byaxis",
                                    options=[{"label":"Type","value":"PrimaryType"},
                                             {"label":"Location","value":"LocationDescription"},
                                             {"label":"District","value":"District"},
                                             {"label":"Year","value":"Year"},
                                             {"label":"Month","value":"Month"},
                                             {"label":"Day","value":"Day"},
                                             {"label":"Weekday","value":"Weekday"},
                                             {"label":"Arrest","value":"Arrest"}],
                                    value="PrimaryType",),
                       style={"width":"49%"})]),
                       html.Div([dcc.Graph(id="my-graph")]),
],className="container")

@app.callback(
    dash.dependencies.Output("my-graph","figure"),
    [dash.dependencies.Input("sxaxis","value"),
     dash.dependencies.Input("syaxis","value"),
     dash.dependencies.Input("bxaxis","value"),
     dash.dependencies.Input("byaxis","value")])

def update_graph(sxax,syax,bxa,bya):
    trace1=[go.Scatter(x=df[sxax],y=df[syax],mode='markers',opacity=0.8,
                       marker={"size":10,},showlegend=False,)]
    trace3=[go.Bar(x=df[bxa],y=df[bya],showlegend=False)]
    trace=trace1+trace3
    text={"PrimaryType":"Type","LocationDescription":"Location","District":"District","Year":"Year",
         "Month":"Month","Day":"Day","Weekday":"Weekday","Arrest":"Arrest"}
    return{"data":trace,
          "layout":go.Layout(height=850,width=1000,)}

# %%
if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [11/May/2019 03:26:34] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [11/May/2019 03:26:34] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [11/May/2019 03:26:34] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [11/May/2019 03:26:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [11/May/2019 03:27:16] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
PrimaryType_df=df['PrimaryType'].unique()
LocationDescription_df=df['LocationDescription'].unique()
District_df=df['District'].unique()
Year_df=df['Year'].unique()
Month_df=df['Month'].unique()
Day_df=df['Day'].unique()
Weekday_df=df['Weekday'].unique()
HourOfDay_df=df['HourOfDay'].unique()
Arrest_df=df['Arrest'].unique()

# %%
@app.callback(
    dash.dependencies.Output("my-graph","figure"),
    [dash.dependencies.Input("sxaxis","value"),
     dash.dependencies.Input("syaxis","value"),
     dash.dependencies.Input("Pie","value"),
     dash.dependencies.Input("bxaxis","value"),
     dash.dependencies.Input("byaxis","value")])

# %%
PrimaryType_c = df.groupby(by='PrimaryType', as_index=False).agg({'ID': pd.Series.nunique})


PrimaryType_df=df['PrimaryType'].unique()
LocationDescription_df=df['LocationDescription'].unique()
District_df=df['District'].unique()
Year_df=df['Year'].unique()
Month_df=df['Month'].unique()
Day_df=df['Day'].unique()
Weekday_df=df['Weekday'].unique()
HourOfDay_df=df['HourOfDay'].unique()
Arrest_df=df['Arrest'].unique()

# %%
def update_graph(sxax,syax,spie,bxa,bya):
    trace1=[go.Scatter(x=df[sxax],y=df[syax],mode='markers',opacity=0.8,
                       marker={"size":10,},showlegend=False,)]
    trace2=[go.Pie(x=df[spie],)]
    trace3=[go.Bar(x=df[bxa],y=df[bya],showlegend=False)]
    trace=trace1+trace2+trace3
    text={"PrimaryType":"Type","LocationDescription":"Location","District":"District","Year":"Year",
         "Month":"Month","Day":"Day","Weekday":"Weekday","Arrest":"Arrest"}
    return{"data":trace,
          "layout":go.Layout(height=850,width=1000,annotations={
              {"x":0.07,"y":1,"xref":"paper","yref":"paper","font":{"size":12},
               "text":f'{text[syax].title()} and {text[syax].title()}',"showarrow":False},
              {"x":0.07,"y":1,"xref":"paper","yref":"paper","font":{"size":12},
               "text":f'{text[bxa].title()} and {text[bya].title()}',"showarrow":False}})}

# %%
annotations={
              {"x":0.07,"y":1,"xref":"paper","yref":"paper","font":{"size":12},
               "text":f'{text[syax].title()} and {text[syax].title()}',"showarrow":False},
              {"x":0.07,"y":1,"xref":"paper","yref":"paper","font":{"size":12},
               "text":f'{text[bxa].title()} and {text[bya].title()}',"showarrow":False

# %%
    html.Div([html.Span("Pie Select",style={'width': '49%', 'display': 'inline-block'}),
              html.Div(dcc.Dropdown(id="Pie",
                                    options=[{"label":"Type","value":"PrimaryType"},
                                             {"label":"Location","value":"LocationDescription"},
                                             {"label":"District","value":"District"},
                                             {"label":"Year","value":"Year"},
                                             {"label":"Month","value":"Month"},
                                             {"label":"Day","value":"Day"},
                                             {"label":"Weekday","value":"Weekday"},
                                             {"label":"Arrest","value":"Arrest"}],
                                    value="District",),
                       style={"width":"49%"})]),

# %%
        
             
             
             
def getCount(df, selected_org):

    totCount = df[df['ORG_CODE_LEVEL_2_SHORT'] == selected_org].AGENCY_INFO_5.count()

    return [html.H2(totCount)]
             
             
             
             
             
             
             s

app.layout = html.Div([
        dcc.Dropdown(
        id='my-dropdown',
        multi=True,
        options=[{'label': i, 'value': i} for i in df['District']])
        dcc.Slider(
        id='year-slider',
        min=df['Year'].min(),
        max=df['Year'].max(),
        value=df['Year'].min(),
        marks={str(year): str(year) for year in df['Year'].unique()},
        step=None)
    html.Div([
        dcc.Graph(
        id='upleft'),
    dcc.Graph(
        id='rtop'),
    dcc.Graph(
        id='rmid'),
    dcc.Graph(
        id='rleft'),

])

@app.callback(
    Output('graph-with-slider', 'figure'),
    [Input('year-slider', 'value')])
def update_figure(selected_year):
    filtered_df = df[df.Year == selected_year]
    traces = []
    for i in filtered_df.PrimaryType.unique():
        df_by_PrimaryType = filtered_df[filtered_df['PrimaryType'] == i]
        traces.append(go.Scatter(
            x=df_by_PrimaryType['XCoordinate'],
            y=df_by_PrimaryType['YCoordinate'],
            text=df_by_PrimaryType['District'],
            mode='markers',
            opacity=0.7,
            marker={
                'size': 15,
                'line': {'width': 0.5, 'color': 'white'}
            },
            name=i
        ))
    return {
        'data': traces,
        'layout': go.Layout(
            xaxis={'type': 'log', 'title': 'XCoordinate'},
            yaxis={'title': 'YCoordinate'},
            margin={'l': 40, 'b': 40, 't': 10, 'r': 10},
            legend={'x': 0, 'y': 1},
            hovermode='closest'
        )
    }

# %%
app.layout = html.Div([
        html.H2('Chicago'),
        dcc.Dropdown(
        id='my-dropdown',
        multi=True,
        options=[{'label': i, 'value': i} for i in df['District']]),
        dcc.Slider(
        id='year-slider',
        min=df['Year'].min(),
        max=df['Year'].max(),
        value=df['Year'].min(),
        marks={str(year): str(year) for year in df['Year'].unique()},
        step=None)])

# %%
#tdf=df.groupby(['Year'])[['ID']].count().reset_index()
#tdf.head()

# %%
data = [dict(
  type = 'bar',
  x = df.Year,
  y = df.PrimaryType,
  mode = 'markers',
  transforms = [dict(
    type = 'groupby',
    groups = df.PrimaryType,
  )]
)]

# %%
app.layout = html.Div([
    html.H2('Chicago'),
    dcc.Dropdown(
        id='my-dropdown',
        multi=True,
        options=[{'label': i, 'value': i} for i in df['District']]
    ),
    dcc.Graph(id='1graph'),
    dcc.Graph(id='2graph')
], className="container")

@app.callback(Output('1graph', 'figure'),
              [Input('my-dropdown', 'value')])

def update_graph(selected_dropdown_value):
    dff = df[df['District'] == selected_dropdown_value]
#    dff=dff.groupby(['Year'])[['ID']].count().reset_index()
    return {
            'data': [
                go.Scatter(
                    x=df['XCoordinate'],
                    y=df['YCoordinate'],
                    text=df['District'],
                    mode='markers',
                    opacity=0.7,
                    marker={
                        'size': 4,
                        'line': {'width': 0.5, 'color': 'white'}
                    },
                    name=i
                ) for i in df.District.unique()
            ],
            'layout': go.Layout(
                xaxis=dict(rangemode='normal'),
                yaxis=dict(rangemode='normal'),
                margin={'l': 40, 'b': 40, 't': 40, 'r': 40},
                legend={'x': 0, 'y': 1},
                hovermode='closest',
                title="Scatter Plot"
            )
    }

# %%
#Sample Table Data

def generate_table(dataframe, max_rows=10):
    return html.Table(
        # Header
        [html.Tr([html.Th(col) for col in dataframe.columns])] +

        # Body
        [html.Tr([
            html.Td(dataframe.iloc[i][col]) for col in dataframe.columns
        ]) for i in range(min(len(dataframe), max_rows))]
    )


external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

app.layout = html.Div(children=[
    html.H4(children='Chicago Crime Table Sample'),
    generate_table(df)
])

# %%
app.layout = html.Div([
    html.Div([
        html.H1("Employment Wage Rigidity"),

    ], style={"text-align": "center"}),
    html.Div(
        dcc.Graph(id="my-graph")

    ),
    html.Div([
        dcc.RangeSlider(
            id='year-slider',
            min=2014,
            max=2018,
            marks={
                2014: '2014',
                2015: '2015',
                2016: '2016',
                2017: '2017',
                2018: '2018'
            },
            value=[2014, 2018]
        )

    ], style={"margin": 20, "padding": 30})

], className="container")


@app.callback(
    dash.dependencies.Output('my-graph', 'figure'),
    [dash.dependencies.Input('year-slider', 'value')])
def update_figure(selected_year):
    pd.options.mode.chained_assignment = None
    dff = df[(df.Year >= selected_year[0]) & (df.Year <= selected_year[1])]
    dff['Date'] = pd.to_datetime(dff['Date']).dt.strftime('%y/%d')
    trace1 = go.Bar(
        y=dff["XCoordinate"],
        x0=dff["Year"],
        mode='lines+markers',
        marker={"size": 3.5},
        name="PrimaryType"

    )
    trace2 = go.Scatter(
        y=dff['Arrest'].count(),
        x=dff["Date"],
        mode='markers',
        marker={"size": 3},
        name="Arrest"

    )
    trace3 = go.Scatter(
        y=dff["District"].count(),
        x=dff["Date"],
        mode='lines',
        marker={"size": 2},
        name="Districtl"

    )
    trace4 = go.Scatter(
        y=dff["LocationDescription"].count(),
        x=dff["Date"],
        mode='lines+markers',
        marker={"size": 3.5},
        name="LocationDescription"

    )
    trace5 = go.Scatter(
        y=dff["XCoordinate"].count(),
        x=dff["Date"],
        mode='lines',
        marker={"size": 2},
        name="XCoordinate"

    )
    trace6 = go.Scatter(
        y=dff["YCoordinate"],
        x=dff["Date"],
        mode='markers',
        marker={"size": 3},
        name="YCoordinate"

    )
    data = [trace1]

    return {
        "data": data,
        "layout": go.Layout(
            title=f"Wage Rigidity for {'-'.join(str(i) for i in selected_year)}",
            xaxis={
                "title": "Year",
                "tickangle": 45,
            },
            yaxis={
                "title": "% of Jobstayers With a Wage Change of Zero",
#                "range": [0, 25],
                "tick0": 0,
                "dtick": 5,
            },

        )

    }

# %%
app.layout = html.Div([
    dcc.Graph(
'data' = [dict(
  type = 'bar',
  x = df.Year,
  y = df.PrimaryType,
  mode = 'markers',
  transforms = [dict(
    type = 'groupby',
    groups = df.PrimaryType,
  )]
)])])

# %%
# scatter plot by district

app.layout = html.Div([
    dcc.Graph(
        id='graph1',
        figure={
            'data': [
                go.Scatter(
                    x=df[df['District'] == i]['XCoordinate'],
                    y=df[df['District'] == i]['YCoordinate'],
                    text=df[df['District'] == i]['District'],
                    mode='markers',
                    opacity=0.7,
                    marker={
                        'size': 4,
                        'line': {'width': 0.5, 'color': 'white'}
                    },
                    name=i
                ) for i in df.District.unique()
            ],
            'layout': go.Layout(
                xaxis=dict(rangemode='normal'),
                yaxis=dict(rangemode='normal'),
                margin={'l': 40, 'b': 40, 't': 40, 'r': 40},
                legend={'x': 0, 'y': 1},
                hovermode='closest',
                title="Scatter Plot"
            )
        }
    )

])

# %%
plt.figure()
sns.barplot(x='Year',
            y='PrimaryType',
            data=df.groupby(['Year'])['PrimaryType'].value_counts().\
                 unstack().reset_index(),
            color='steelblue').\
            set_title("CHICAGO MURDER RATES: 2001 - 2018")

# %%
app.layout=html.Dif([
    dcc.Dropdown(
    id="LeftDropdown",
    multi=True,
    options=[{'label':i,'value':i} for i in df['LocationDescription'].unique()],)
    
    dcc.Dropdown(
    id="RightDropdown",
    multi=True,
    options=[{'label':i,'value':i} for i in df['PrimaryType'].unique()]),
    
    dcc.Checklist(
    id="SelectAll",
    options=[{'label':'Select All','value':1}]),
        values=[],
    
    dcc.Slider(
        id='YearSlider',
        min=df['Year'].min(),
        max=df['Year'].max(),
        value=df['Year'].max(),
        marks={str(year): str(year) for year in df['Year'].unique()}
    ), style={'width': '49%', 'padding': '0px 20px 20px 20px'})
])

# %%
@app.callback(
    Output('ScatterPlot','figure'),
    [Output('LeftDropdown','value'),
    [Input('SelectAll','values')]]

# %%
@app.callback(
    dash.dependencies.Output('crossfilter-indicator-scatter', 'figure'),
    [dash.dependencies.Input('crossfilter-xaxis-column', 'value'),
     dash.dependencies.Input('crossfilter-yaxis-column', 'value'),
     dash.dependencies.Input('crossfilter-xaxis-type', 'value'),
     dash.dependencies.Input('crossfilter-yaxis-type', 'value'),
     dash.dependencies.Input('crossfilter-year--slider', 'value')])



#available_indicators = df['LocationDescription'].unique()

app.layout = html.Div([
    html.Div([

        html.Div([
            dcc.Dropdown(
                id='LeftDropdown',
                multi=True,
                options=[{'label': i, 'value': i} for i in df['LocationDescription'].unique()],
            ),
#            dcc.RadioItems(
#                id='crossfilter-xaxis-type',
#                options=[{'label': i, 'value': i} for i in ['Linear', 'Log']],
#                value='Linear',
#                labelStyle={'display': 'inline-block'}
#            )
        ],
        style={'width': '49%', 'display': 'inline-block'}),

        html.Div([
            dcc.Dropdown(
                id='RightDropdown',
                multi=True,
                options=[{'label': i, 'value': i} for i in df['PrimaryType'].unique()],
            ),
#            dcc.RadioItems(
#                id='crossfilter-yaxis-type',
#                options=[{'label': i, 'value': i} for i in ['Linear', 'Log']],
#                value='Linear',
#                labelStyle={'display': 'inline-block'}
#            )
        ], style={'width': '49%', 'float': 'right', 'display': 'inline-block'})
    ], style={
        'borderBottom': 'thin lightgrey solid',
        'backgroundColor': 'rgb(250, 250, 250)',
        'padding': '10px 5px'
    }),
    
    
        dcc.Checklist(id='select-all',
                  options=[{'label': 'Select All', 'value': 1}], values=[])


    html.Div([
        dcc.Graph(
            id='crossfilter-indicator-scatter',
            hoverData={'points': [{'customdata': 'something'}]}
        )
    ], style={'width': '49%', 'display': 'inline-block', 'padding': '0 20'}),
    html.Div([
        dcc.Graph(id='x-time-series'),
        dcc.Graph(id='y-time-series'),
    ], style={'display': 'inline-block', 'width': '49%'}),

    html.Div(dcc.Slider(
        id='crossfilter-year--slider',
        min=df['Year'].min(),
        max=df['Year'].max(),
        value=df['Year'].max(),
        marks={str(year): str(year) for year in df['Year'].unique()}
    ), style={'width': '49%', 'padding': '0px 20px 20px 20px'})
])


@app.callback(
    dash.dependencies.Output('crossfilter-indicator-scatter', 'figure'),
    [dash.dependencies.Input('crossfilter-xaxis-column', 'value'),
     dash.dependencies.Input('crossfilter-yaxis-column', 'value'),
#     dash.dependencies.Input('crossfilter-xaxis-type', 'value'),
#     dash.dependencies.Input('crossfilter-yaxis-type', 'value'),
     dash.dependencies.Input('crossfilter-year--slider', 'value')])
def update_graph(xaxis_column_name, yaxis_column_name,
#                 xaxis_type, yaxis_type,
                 year_value):
    dff = df[df['Year'] == year_value]

    return {
        'data': [go.Scatter(
            x=dff[dff['LocationDescription'] == selected_dropdown_value],
            y=dff[dff['PrimaryType'] == selected_dropdown_value],
            text=dff[dff['LocationDescription'] == selected_dropdown_value],
            customdata=dff[dff['LocationDescription'] == selected_dropdown_value],
            mode='markers',
            marker={
                'size': 15,
                'opacity': 0.5,
                'line': {'width': 0.5, 'color': 'white'}
            }
        )],
        'layout': go.Layout(
            xaxis={
                'title': xaxis_column_name,
                'type': 'linear' if xaxis_type == 'Linear' else 'log'
            },
            yaxis={
                'title': yaxis_column_name,
                'type': 'linear' if yaxis_type == 'Linear' else 'log'
            },
            margin={'l': 40, 'b': 30, 't': 10, 'r': 0},
            height=450,
            hovermode='closest'
        )
    }


def create_time_series(dff, axis_type, title):
    return {
        'data': [go.Scatter(
            x=dff['Year'],
            y=dff['District'],
            mode='lines+markers'
        )],
        'layout': {
            'height': 225,
            'margin': {'l': 20, 'b': 30, 'r': 10, 't': 10},
            'annotations': [{
                'x': 0, 'y': 0.85, 'xanchor': 'left', 'yanchor': 'bottom',
                'xref': 'paper', 'yref': 'paper', 'showarrow': False,
                'align': 'left', 'bgcolor': 'rgba(255, 255, 255, 0.5)',
                'text': title
            }],
            'yaxis': {'type': 'linear' if axis_type == 'Linear' else 'log'},
            'xaxis': {'showgrid': False}
        }
    }


@app.callback(
    dash.dependencies.Output('x-time-series', 'figure'),
    [dash.dependencies.Input('crossfilter-indicator-scatter', 'hoverData'),
     dash.dependencies.Input('crossfilter-xaxis-column', 'value'),
     dash.dependencies.Input('crossfilter-xaxis-type', 'value')])
def update_y_timeseries(hoverData, xaxis_column_name, axis_type):
    country_name = hoverData['points'][0]['customdata']
    dff = df[df['PrimaryType'] == country_name]
    dff = dff[dff['LocationDescription'] == xaxis_column_name]
    title = '<b>{}</b><br>{}'.format(country_name, xaxis_column_name)
    return create_time_series(dff, axis_type, title)


@app.callback(
    dash.dependencies.Output('y-time-series', 'figure'),
    [dash.dependencies.Input('crossfilter-indicator-scatter', 'hoverData'),
     dash.dependencies.Input('crossfilter-yaxis-column', 'value'),
     dash.dependencies.Input('crossfilter-yaxis-type', 'value')])
def update_x_timeseries(hoverData, yaxis_column_name, axis_type):
    dff = df[df['PrimaryType'] == hoverData['points'][0]['customdata']]
    dff = dff[dff['LocationDescription'] == yaxis_column_name]
    return create_time_series(dff, axis_type, yaxis_column_name)

# %%
df2 = pd.read_csv(
    'https://gist.githubusercontent.com/chriddyp/'
    'cb5392c35661370d95f300086accea51/raw/'
    '8e0768211f6b747c0db42a9ce9a0937dafcbd8b2/'
    'indicators.csv')
df2.head()

# %%
#Primary type over time
data = [dict(
  type = 'bar',
  x = df.Year,
  y = df.PrimaryType,
  mode = 'markers',
  transforms = [dict(
    type = 'groupby',
    groups = df.PrimaryType,
  )]
)]

off.iplot({'data': data}, validate=False)
