# %%
import pandas as pd
import geopandas as gpd
import matplotlib as plt

# %%
df=pd.read_csv("/Users/nathanmitch/Desktop/holdingout.csv")  # doctest: +SKIP

# %%
map_df = gpd.read_file(df)
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-e413628ba74f> in <module>
# ----> 1 map_df = gpd.read_file(df)
#       2 # check data type so we can see that this is not a normal dataframe, but a GEOdataframe
#       3 map_df.head()
#
# /anaconda3/envs/sundress/lib/python3.7/site-packages/geopandas/io/file.py in read_file(filename, bbox, **kwargs)
#      69
#      70     with fiona_env():
# ---> 71         with reader(path_or_bytes, **kwargs) as features:
#      72             crs = features.crs
#      73             if bbox is not None:
#
# /anaconda3/envs/sundress/lib/python3.7/site-packages/fiona/env.py in wrapper(*args, **kwargs)
#     394     def wrapper(*args, **kwargs):
#     395         if local._env:
# --> 396             return f(*args, **kwargs)
#     397         else:
#     398             if isinstance(args[0], str):
#
# /anaconda3/envs/sundress/lib/python3.7/site-packages/fiona/__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     247             path = ParsedPath(path, archive, scheme)
#     248         else:
# --> 249             path = parse_path(fp)
#     250
#     251         if mode in ('a', 'r'):
#
# /anaconda3/envs/sundress/lib/python3.7/site-packages/fiona/path.py in parse_path(path)
#     129         return UnparsedPath(path)
#     130
# --> 131     elif path.startswith('/vsi'):
#     132         return UnparsedPath(path)
#     133
#
# /anaconda3/envs/sundress/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'startswith'

# %%
df.head()
# Out:
#          ID Case Number                    Date                      Block  \
# 0  11663630    JC234612  04/22/2019 11:35:00 PM            041XX W 25TH ST
# 1  11663656    JC234605  04/22/2019 11:32:00 PM        006XX N LARAMIE AVE
# 2  11663650    JC234610  04/22/2019 11:30:00 PM      091XX S GREENWOOD AVE
# 3  11663815    JC234809  04/22/2019 11:30:00 PM          067XX N MOZART ST
# 4  11663693    JC234650  04/22/2019 11:30:00 PM  047XX S COTTAGE GROVE AVE
#
#    IUCR     Primary Type     Description Location Description  Arrest  \
# 0  1310  CRIMINAL DAMAGE     TO PROPERTY            RESIDENCE   False
# 1  0460          BATTERY          SIMPLE             SIDEWALK   False
# 2  0460          BATTERY          SIMPLE        PARK PROPERTY   False
# 3  0820            THEFT  $500 AND UNDER            RESIDENCE   False
# 4  0610         BURGLARY  FORCIBLE ENTRY     DEPARTMENT STORE   False
#
#    Domestic  ...  Longitude                       Location  \
# 0      True  ... -87.727011  (41.846047463, -87.727011485)
# 1     False  ... -87.755490  (41.891905336, -87.755490053)
# 2     False  ... -87.597361  (41.728594642, -87.597361383)
# 3     False  ... -87.701012  (42.003851203, -87.701012017)
# 4     False  ... -87.606558  (41.809305232, -87.606558389)
#
#    Historical Wards 2003-2015  Zip Codes Community Areas  Census Tracts  \
# 0                        14.0    21569.0            32.0          194.0
# 1                        11.0    22216.0            26.0          673.0
# 2                         9.0    21546.0            43.0          472.0
# 3                        42.0    22528.0            20.0           40.0
# 4                         1.0    21192.0             5.0          461.0
#
#    Wards  Boundaries - ZIP Codes Police Districts  Police Beats
# 0   28.0                    57.0             21.0         161.0
# 1   45.0                    32.0             25.0          67.0
# 2   35.0                    61.0             19.0         246.0
# 3   27.0                    12.0             11.0          46.0
# 4   10.0                    10.0             24.0         116.0
#
# [5 rows x 30 columns]
